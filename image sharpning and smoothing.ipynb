# %%
# Importing the modules
import  cv2
import numpy as np
from google.colab.patches import cv2_imshow # Import cv2_imshow

# Reading the image
image = cv2.imread('/content/logo.png')

# Creating the kernel with numpy
kernel2 = np.ones((5, 5), np.float32)/25

# Applying the filter
img = cv2.filter2D(src=image, ddepth=-1, kernel=kernel2)

# showing the image
cv2_imshow(image)  # Use cv2_imshow instead of cv2.imshow
cv2_imshow(img)    # Use cv2_imshow instead of cv2.imshow

# cv2.waitKey() and cv2.destroyAllWindows() are not needed in Colab
# cv2.waitKey()
# cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=260x260>
# <PIL.Image.Image image mode=RGB size=260x260>

# %%
# Importing the modules
import cv2
import numpy as np
from google.colab.patches import cv2_imshow # Import cv2_imshow

# Reading the image
image = cv2.imread('/content/logo.png')

# Applying the filter
averageBlur = cv2.blur(image, (5, 5))

# Showing the image
cv2_imshow(image)  # Use cv2_imshow instead of cv2.imshow
cv2_imshow(averageBlur)    # Use cv2_imshow instead of cv2.imshow

# cv2.waitKey() and cv2.destroyAllWindows() are not needed in Colab
# cv2.waitKey()
# cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=260x260>
# <PIL.Image.Image image mode=RGB size=260x260>

# %%
# Importing the module
import cv2
import numpy as np
from google.colab.patches import cv2_imshow # Import cv2_imshow

# Reading the image
image = cv2.imread('/content/logo.png')

# Applying the filter
gaussian = cv2.GaussianBlur(image, (3, 3), 0)

# Showing the image

cv2_imshow(image)  # Use cv2_imshow instead of cv2.imshow
cv2_imshow(averageBlur)    # Use cv2_imshow instead of cv2.imshow

# cv2.waitKey() and cv2.destroyAllWindows() are not needed in Colab
# cv2.waitKey()
# cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=260x260>
# <PIL.Image.Image image mode=RGB size=260x260>

# %%
# Importing the modules
import cv2
import numpy as np
from google.colab.patches import cv2_imshow # Import cv2_imshow

# Reading the image
image = cv2.imread('/content/logo.png')

# Applying the filter
medianBlur = cv2.medianBlur(image, 9)

# Showing the image
cv2_imshow(image)  # Use cv2_imshow instead of cv2.imshow
cv2_imshow(averageBlur)    # Use cv2_imshow instead of cv2.imshow

# cv2.waitKey() and cv2.destroyAllWindows() are not needed in Colab
# cv2.waitKey()
# cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=260x260>
# <PIL.Image.Image image mode=RGB size=260x260>

# %%
# Importing the modules
import cv2
import numpy as np
from google.colab.patches import cv2_imshow # Import cv2_imshow

# Reading the image
image = cv2.imread('/content/logo.png')

# Applying the filter
bilateral = cv2.bilateralFilter(image, 9, 75, 75)

# Showing the image
cv2_imshow(image)  # Use cv2_imshow instead of cv2.imshow
cv2_imshow(averageBlur)    # Use cv2_imshow instead of cv2.imshow

# cv2.waitKey() and cv2.destroyAllWindows() are not needed in Colab
# cv2.waitKey()
# cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=260x260>
# <PIL.Image.Image image mode=RGB size=260x260>
